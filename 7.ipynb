# %%
import numpy as np
import pandas as pd

df=pd.read_csv("datasets/antropometria-dataset.csv")
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
da=pd.DataFrame
da.hist(data=df,
        column=["sistol","diastol"],
        bins=15)
plt.show()

# %%
da.hist(data=df,
                 column=["peso","cintura"],
                 bins=15)
plt.show()

# %%
X=df["peso"].values
y=df["cintura"].values
plt.scatter(X,y,c="g",)
plt.show()

# %%
df_rep=df.loc[:,["sexo","sistol","diastol","peso"]]
df_rep

sex1=df["sexo"]==1
df1=df[sex1]
pd.DataFrame.hist(data=df1,
       column="peso",bins=25)
plt.show()

# %%
df_rep.set_index("sexo",
                inplace=True)
df_rep.head()
# Out:
#       sistol  diastol   peso
# sexo
# 2      63.25    53.25  73.70
# 2      70.00    50.00  35.65
# 2      70.50    41.00  54.80
# 1      71.00    64.00  33.40
# 2      72.00    53.50  97.95

# %%
sex1=df["sexo"]==1
df1=df[sex1]
pd.DataFrame.hist(data=df1,
       column="peso",bins=30)
plt.show()

sex2=df["sexo"]==2
df1=df[sex2]
pd.DataFrame.hist(data=df1,
       column="cintura",bins=30)
plt.show()

# %%
X=df["sistol"].values
y=df["diastol"].values

plt.scatter(X,y,c="g")
plt.show()
