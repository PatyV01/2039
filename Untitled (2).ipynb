# %% [markdown]
# Dentro de este documento se realizara la evidencia final de la materia visualización de datos para la toma de decisiones
#
# La evidencia presentada tendra como objetivo contestar pregutnas que tiene que ver las caracteriticas de las tallas de las vestimentas.
#
# Las variables criticas de analizar son: el peso, edad, sexo, cintura, cadera, talla y estado.
#
# Las pregutnas a contestar son:
#  ¿Cual es la mediana del peso?
#  ¿Cuantas entidades estan registradas dentro de la base de datos?
#  ¿La talla va incrementado con respecto a la edad de la persona?
#  Dentro de dos graficas demostrar las tallas de cadera que hay entre generos
#  Dos digramas de dispersión de mujeres y hombres con respecto a su peso
