# %%
import numpy as np
import pandas as pd
df=pd.read_excel("datasets/Canada.xlsx",
                sheet_names="Canada by Citizenship",
                skiprows=range(20),
                skipfooter=2,
                engine="openpyxl")

# %%
df.head(2)
#df.columns
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    ..    ..    ..    ..  ...    ..    ..    ..    ..    ..    ..     1
# 1  1426  1094  1187  1134  ...  7083  6750  6669  6705  6922  8591  8956
#
#      2012 2013  Unnamed: 38
# 0     1.0  NaN          NaN
# 1  8846.0  NaN          NaN
#
# [2 rows x 39 columns]

# %%
df.drop(["AREA","REG","DEV","Type","Coverage"],
        axis=1,
        inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-357cd6b413b6> in <module>
#       1 df.drop(["AREA","REG","DEV","Type","Coverage"],
#       2         axis=1,
# ----> 3         inplace=True)
#       4
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['AREA' 'REG' 'DEV'] not found in axis"

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',    'AreaName',     'RegName',
#                 1980,          1981,          1982,          1983,
#                 1984,          1985,          1986,          1987,
#                 1988,          1989,          1990,          1991,
#                 1992,          1993,          1994,          1995,
#                 1996,          1997,          1998,          1999,
#                 2000,          2001,          2002,          2003,
#                 2004,          2005,          2006,          2007,
#                 2008,          2009,          2010,          2011,
#                 2012,          2013, 'Unnamed: 38'],
#       dtype='object')

# %%
df.rename(columns={"OdName":"Country",
                  "AreaName":"Continent",
                  "RegName":"Regions"},
         inplace=True)
df.head()
# Out:
#          Type    Coverage         Continent           Regions  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 2  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 3  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
# 4  Immigrants  Foreigners            Africa   Southern Africa  1041  1126
#
#    1982  1983  1984  1985  ...   2005   2006   2007   2008   2009   2010  \
# 0    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 1  1426  1094  1187  1134  ...   7083   6750   6669   6705   6922   8591
# 2    44    32    42    30  ...   2802   2834   2951   3034   3255   3369
# 3  1348   936   842   840  ...  11323  12705  11750  13456  16320  19271
# 4   791   387   297   327  ...   1012   1148   1230   1184   1235   1306
#
#     2011     2012 2013  Unnamed: 38
# 0      1      1.0  NaN          NaN
# 1   8956   8846.0  NaN          NaN
# 2   3146   4602.0  NaN          NaN
# 3  15712  15453.0  NaN          NaN
# 4   1049   1348.0  NaN          NaN
#
# [5 rows x 39 columns]

# %%
df.set_index("Continent", inplace=True)

# %%
df.head(2)
# Out:
#                         Type    Coverage           Regions  1980  1981  1982  \
# Continent
# Northern America  Immigrants    Citizens  Northern America    ..    ..    ..
# Africa            Immigrants  Foreigners    Eastern Africa  1471  1641  1426
#
#                   1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  \
# Continent                                 ...
# Northern America    ..    ..    ..    ..  ...    ..    ..    ..    ..    ..
# Africa            1094  1187  1134  1454  ...  7083  6750  6669  6705  6922
#
#                   2010  2011    2012  2013  Unnamed: 38
# Continent
# Northern America    ..     1     1.0   NaN          NaN
# Africa            8591  8956  8846.0   NaN          NaN
#
# [2 rows x 38 columns]

# %%
df["Total"]=df.iloc[:,4:].sum(axis=1)

# %%
df.head(2)
# Out:
#                         Type    Coverage           Regions  1980  1981  1982  \
# Continent
# Northern America  Immigrants    Citizens  Northern America    ..    ..    ..
# Africa            Immigrants  Foreigners    Eastern Africa  1471  1641  1426
#
#                   1983  1984  1985  1986  ...  2006  2007  2008  2009  2010  \
# Continent                                 ...
# Northern America    ..    ..    ..    ..  ...    ..    ..    ..    ..    ..
# Africa            1094  1187  1134  1454  ...  6750  6669  6705  6922  8591
#
#                   2011    2012 2013  Unnamed: 38    Total
# Continent
# Northern America     1     1.0  NaN          NaN      6.0
# Africa            8956  8846.0  NaN          NaN  24717.0
#
# [2 rows x 39 columns]

# %%
years=list(map(str,range(1980,2014)))

# %%
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use("ggplot")

# %%
df_continets=df.groupby("Continent",
                       axis=0).sum()

# %%
df_continets
# Out:
#                                           1993     1995      1996      2012  \
# Continent
# Africa                                 16531.0  14806.0   15700.0   38083.0
# Africa Total                           16531.0  14806.0   15700.0   38083.0
# Asia                                   98737.0  90424.0  103030.0  152218.0
# Asia Total                             98737.0  90424.0  103030.0  152218.0
# Europe                                 62937.0  55764.0   55642.0   29177.0
# Europe Total                           62937.0  55764.0   55642.0   29177.0
# Latin America and the Caribbean        33840.0  20262.0   18645.0   27173.0
# Latin America and the Caribbean Total  33840.0  20262.0   18645.0   27173.0
# Northern America                        7438.0   4891.0    5516.0    7892.0
# Oceania                                 2566.0   1565.0    1552.0    1679.0
# Oceania Total                           2566.0   1565.0    1552.0    1679.0
# Unknown                                34589.0  25152.0   25986.0    1681.0
#
#                                        2013  Unnamed: 38     Total
# Continent
# Africa                                  0.0          0.0   85120.0
# Africa Total                            0.0          0.0   85120.0
# Asia                                    0.0          0.0  444409.0
# Asia Total                              0.0          0.0  444409.0
# Europe                                  0.0          0.0  203520.0
# Europe Total                            0.0          0.0  203520.0
# Latin America and the Caribbean         0.0          0.0   99920.0
# Latin America and the Caribbean Total   0.0          0.0   99920.0
# Northern America                        0.0          0.0   25737.0
# Oceania                                 0.0          0.0    7362.0
# Oceania Total                           0.0          0.0    7362.0
# Unknown                                 0.0          0.0   87408.0

# %%
#color_list=["gold","yellowgreen","lightcoral","lightskyblue","lightgreen","pink","red"]
#explode_list=[0.1,0,0,0,0.2,0.3]

df_continets["Total"].plot(kind="pie",
                           figsize=(5,6),
                           autopct="%10.1f%%",
                           startangle=90,
                           shadow=True)
plt.show()
